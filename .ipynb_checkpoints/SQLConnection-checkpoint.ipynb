# %%
# To use this create a DSN conneciton with the following properties: 
# SQL authorisation
# Server: KG-Training22
# Default Database: algo
# Application intent: Readwrite

DSN_Name = 'traderDSN'
Login_ID = 'basic'
pwd = 'pwd1'

# Create a DSN connection and a cursor to do stuff. 
from sqlalchemy import create_engine
import pandas as pd

# The engine does the same job as a connection and a cursor
engine = create_engine(r'mssql+pyodbc://'+Login_ID+':'+pwd+'@'+ DSN_Name) 

# Build query here:
query = ''' 
SELECT * FROM newtab
'''

# Importing a Pandas Dataframe: 
df1 = pd.read_sql(query,engine)

# Display
df1
# Out:
#     BusinessEntityID  TerritoryID  SalesQuota   Bonus  CommissionPct  \
# 0                274          NaN         NaN     0.0          0.000
# 1                275          2.0    300000.0  4100.0          0.012
# 2                276          4.0    250000.0  2000.0          0.015
# 3                277          3.0    250000.0  2500.0          0.015
# 4                278          6.0    250000.0   500.0          0.010
# 5                279          5.0    300000.0  6700.0          0.010
# 6                280          1.0    250000.0  5000.0          0.010
# 7                281          4.0    250000.0  3550.0          0.010
# 8                282          6.0    250000.0  5000.0          0.015
# 9                283          1.0    250000.0  3500.0          0.012
# 10               284          1.0    300000.0  3900.0          0.019
# 11               285          NaN         NaN     0.0          0.000
# 12               286          9.0    250000.0  5650.0          0.018
# ...

# %%
# Get current time for creating custom tables:
from datetime import datetime
now = datetime.now()
now_s = now.strftime('%H%M_%d%m%y')
now_s

# Writing to a Pandas dataframe:
tablename = 'tbl1'

# if exists flag is important.
#df1.to_sql(tablename+now_s,engine, if_exists='fail')
df1.to_sql(tablename+now_s, engine, if_exists='replace')
